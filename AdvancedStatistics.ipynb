# %% [markdown]
# ## Problem 1
#
# A physiotherapist with a male football team is interested in studying the relationship between foot injuries and the positions at which the players play from the data collected
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.1 What is the probability that a randomly chosen player would suffer an injury?
#
# 1.2 What is the probability that a player is a forward or a winger?
#
# 1.3 What is the probability that a randomly chosen player plays in a striker position and has a foot injury?
#
# 1.4 What is the probability that a randomly chosen injured player is a striker?
#
# 1.5 What is the probability that a randomly chosen injured player is either a forward or an attacking midfielder?

# %% [markdown]
# **Solution:**
# 1.1. To find the probability that a randomly chosen player would suffer an injury, we need to divide the total number of injured players by the total number of players:
#
# Probability of a randomly chosen player suffering an injury = (Number of injured players) / (Total number of players) = 145/235 ≈ 0.617
#
# **Therefore, the probability that a randomly chosen player would suffer an injury is approximately 0.617.**
#
# 1.2. To find the probability that a player is a forward or a winger, we need to add the number of forwards and wingers and divide it by the total number of players:
#
# Probability of a player being a forward or a winger = (Number of forwards) + (Number of wingers) / (Total number of players) = (94 + 29) / 235 ≈ 0.553
#
# **Therefore, the probability that a player is a forward or a winger is approximately 0.553.**
#
# 1.3. To find the probability that a randomly chosen player plays in a striker position and has a foot injury, we need to divide the number of injured players who play in the striker position by the total number of players:
#
# Probability of a player being in striker position and having a foot injury = (Number of injured strikers) / (Total number of players) = 45/235 ≈ 0.191
#
# **Therefore, the probability that a randomly chosen player plays in a striker position and has a foot injury is approximately 0.191.**
#
# 1.4. To find the probability that a randomly chosen injured player is a striker, we need to divide the number of injured strikers by the total number of injured players:
#
# Probability of an injured player being a striker = (Number of injured strikers) / (Total number of injured players) = 45/145 ≈ 0.310
#
# **Therefore, the probability that a randomly chosen injured player is a striker is approximately 0.310.**
#
# 1.5. To find the probability that a randomly chosen injured player is either a forward or an attacking midfielder, we need to add the number of injured forwards and attacking midfielders and divide it by the total number of injured players:
#
# Probability of an injured player being a forward or an attacking midfielder = (Number of injured forwards) + (Number of injured attacking midfielders) / (Total number of injured players) = (56 + 24) / 145 ≈ 0.690
#
# **Therefore, the probability that a randomly chosen injured player is either a forward or an attacking midfielder is approximately 0.690.**

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#1.1 Solution
num_injured_players = 145
total_players = 235
probability = num_injured_players / total_players
print(probability)
# Out:
# 0.6170212765957447

# %%
#1.2 Solution
num_forwards = 94
num_wingers = 29
total_players = 235

probability = (num_forwards + num_wingers) / total_players

print(probability)
# Out:
# 0.5234042553191489

# %%
#1.3 Solution 

num_injured_strikers = 45
total_players = 235

probability = num_injured_strikers / total_players

print(probability)
# Out:
# 0.19148936170212766

# %%
#1.4 Solution

num_injured_strikers = 45
total_injured_players = 145

probability = num_injured_strikers / total_injured_players

print(probability)
# Out:
# 0.3103448275862069

# %%
#1.5 Solution 

num_injured_forwards = 56
num_injured_attacking_midfielders = 24
total_injured_players = 145

probability = (num_injured_forwards + num_injured_attacking_midfielders) / total_injured_players

print(probability)
# Out:
# 0.5517241379310345

# %% [markdown]
# Problem 2
#
# An independent research organization is trying to estimate the probability that an accident at a nuclear power plant will result in radiation leakage. The types of accidents possible at the plant are, fire hazards, mechanical failure, or human error. The research organization also knows that two or more types of accidents cannot occur simultaneously.
#
# According to the studies carried out by the organization, the probability of a radiation leak in case of a fire is 20%, the probability of a radiation leak in case of a mechanical 50%, and the probability of a radiation leak in case of a human error is 10%. The studies also showed the following;
#
# The probability of a radiation leak occurring simultaneously with a fire is 0.1%.
# The probability of a radiation leak occurring simultaneously with a mechanical failure is 0.15%.
# The probability of a radiation leak occurring simultaneously with a human error is 0.12%.
# On the basis of the information available, answer the questions below:
#
# 2.1 What are the probabilities of a fire, a mechanical failure, and a human error respectively?
#
# 2.2 What is the probability of a radiation leak?
#
# 2.3 Suppose there has been a radiation leak in the reactor for which the definite cause is not known. What is the probability that it has been caused by:
#
# A Fire.
# A Mechanical Failure.
# A Human Error.

# %% [markdown]
# Solution:
#
# We need to use Bayes' Theorem to calculate the unconditional probabilities of the different events.
#
# To use Bayes' Theorem, we need to know the prior probabilities of the events (i.e., the probabilities of the events before we observe any information about whether a radiation leak has occurred), as well as the conditional probabilities of a radiation leak given each of the events.
#
# Let's denote the events as follows:
#
# F: Fire
# M: Mechanical failure
# H: Human error
# R: Radiation leak
#
# We are given:
#
# P(R|F) = 0.20 (the probability of a radiation leak given that there is a fire)
# P(R|M) = 0.50 (the probability of a radiation leak given that there is a mechanical failure)
# P(R|H) = 0.10 (the probability of a radiation leak given that there is a human error)
# P(R) = ? (the probability of a radiation leak)
# We are also given:
#
# P(F and M) = 0 (the probability of both a fire and a mechanical failure occurring simultaneously)
# P(F and H) = 0 (the probability of both a fire and a human error occurring simultaneously)
# P(Mand H) = 0 (the probability of both a mechanical failure and a human error occurring simultaneously)
#
#
# Using the Law of Total Probability, we can write:
#
# P(R) = P(R|F) * P(F) + P(R|M) * P(M) + P(R|H) * P(H)
#
# We know that P(F and M) = P(F and H) = P(M and H) = 0, which means that F, M, and H are mutually exclusive events. So we can write:
#
# P(F or M or H) = P(F) + P(M) + P(H)
#
# Since these events are mutually exclusive, we can use the addition rule of probability to write:
#
# P(F or M or H) = P(F) + P(M) + P(H) = 1
#
# Therefore, we have:
#
# P(H) = 1 - P(F) - P(M)
# Using the conditional probabilities and the formula for P(R) above, we can substitute P(H) in terms of P(F) and P(M):
#
# P(R) = P(R|F) * P(F) + P(R|M) * P(M) + P(R|H) * (1 - P(F) - P(M))
#
# Now we need to solve for P(F), P(M), and P(R):
#
# To find P(F), we can use the fact that the probability of a radiation leak occurring simultaneously with a fire is 0.1%, which means:
#
# P(R and F) = P(R|F) * P(F) = 0.001
#
# Solving for P(F):
#
# 0.001 = 0.20 * P(F)
# P(F) = 0.001 / 0.20 = 0.005
#
# To find P(M), we can use the fact that the probability of a radiation leak occurring simultaneously with a mechanical failure is 0.15%, which means:
#
# P(R and M) = P(R|M) * P(M) = 0.0015
#
# Solving for P(M):
#
# 0.0015 = 0.50 * P(M)
# P(M) = 0.0015 / 0.50 = 0.003
#
# Solving for P(H):
#
# P(H) = 1 - P(F) - P(M)
# = 1 - 0.005 - 0.003
# = 0.992
#
# Finally, we can substitute the values we found for P(F) and P(M) in the formula for P(R) to get:
#
# P(R) = P(R|F) * P(F) + P(R|M) * P(M) + P(R|H) * (1 - P(F) - P(M))
# = 0.20 * 0.005 + 0.50 * 0.003 + 0.10 * (1 - 0.005 - 0.003)
# = 0.1005
#
# Therefore, the probability of a radiation leak is 10.05%.
#
# 2.3 we can use Bayes' Theorem again. We want to find the probability of each cause given that a radiation leak has occurred:
#
# P(F|R) = P(R|F) * P(F) / P(R) = 0.20 * 0.005 / 0.1005 = 0.0099 or approximately 1%
#
# P(M|R) = P(R|M) * P(M) / P(R) = 0.50 * 0.003 / 0.1005 = 0.0149 or approximately 1.5%
#
# P(H|R) = P(R|H) * P(H) / P(R) = 0.10 * (1 -0.005 - 0.003) / 0.1005 = 0.0746 or approximately 7.5%
#
# Therefore, the probability that the radiation leak was caused by a fire is approximately 1%, the probability that it was caused by a mechanical failure is approximately 1.5%, and the probability that it was caused by human error is approximately 7.5%.

# %%
#2.1 Solution

# Conditional probabilities
P_R_given_F = 0.20
P_R_given_M = 0.50
P_R_given_H = 0.10

# Probability of simultaneous events
P_RF = 0.001
P_RM = 0.0015

# Solve for P(F)
P_F = P_RF / P_R_given_F

# Solve for P(M)
P_M = P_RM / P_R_given_M

# Solve for P(H)
P_H = 1 - P_F - P_M

print("P(F):", P_F)
print("P(M):", P_M)
print("P(H):", P_H)
# Out:
# P(F): 0.005
# P(M): 0.003
# P(H): 0.992

# %%
#2.2 Solution
# Solve for P(R)
P_R = P_R_given_F * P_F + P_R_given_M * P_M + P_R_given_H * P_H
print("P(R):", P_R)
# Out:
# P(R): 0.10170000000000001

# %%
#2.3 Solution

# Given probabilities
p_r_given_f = 0.20
p_r_given_m = 0.50
p_r_given_h = 0.10
p_f_and_m = 0
p_f_and_h = 0
p_m_and_h = 0

# Using the Law of Total Probability to calculate P(R)
p_f = 0.005
p_m = 0.003
p_h = 1 - p_f - p_m
p_r = p_r_given_f * p_f + p_r_given_m * p_m + p_r_given_h * p_h

# Using Bayes' Theorem to calculate P(F|R), P(M|R), and P(H|R)
p_f_given_r = p_r_given_f * p_f / p_r
p_m_given_r = p_r_given_m * p_m / p_r
p_h_given_r = p_r_given_h * p_h / p_r

print("P(F|R) =", p_f_given_r)
print("P(M|R) =", p_m_given_r)
print("P(H|R) =", p_h_given_r)
# Out:
# P(F|R) = 0.00983284169124877
# P(M|R) = 0.014749262536873154
# P(H|R) = 0.9754178957718781

# %% [markdown]
# Problem 3:
#
# The breaking strength of gunny bags used for packaging cement is normally distributed with a mean of 5 kg per sq. centimeter and a standard deviation of 1.5 kg per sq. centimeter. The quality team of the cement company wants to know the following about the packaging material to better understand wastage or pilferage within the supply chain;
#
# Answer the questions below based on the given information; (Provide an appropriate visual representation of your answers, without which marks will be deducted)
#
#
#
# 3.1 What proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm?
#
# 3.2 What proportion of the gunny bags have a breaking strength at least 3.6 kg per sq cm.?
#
# 3.3 What proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm.?
#
# 3.4 What proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm.?

# %%
import scipy.stats as stats

# Define the normal distribution
mu = 5 # Mean
sigma = 1.5 # Standard deviation
dist = stats.norm(mu, sigma)

# Problem 3.1: P(X < 3.17)
prob_1 = dist.cdf(3.17)
print("Probability of breaking strength < 3.17 kg/sq cm:", prob_1)

# Problem 3.2: P(X >= 3.6)
prob_2 = 1 - dist.cdf(3.6)
print("Probability of breaking strength >= 3.6 kg/sq cm:", prob_2)

# Problem 3.3: P(5 <= X <= 5.5)
prob_3 = dist.cdf(5.5) - dist.cdf(5)
print("Probability of breaking strength between 5 and 5.5 kg/sq cm:", prob_3)

# Problem 3.4: P(X < 3 or X > 7.5)
prob_4 = dist.cdf(3) + (1 - dist.cdf(7.5))
print("Probability of breaking strength NOT between 3 and 7.5 kg/sq cm:", prob_4)
# Out:
# Probability of breaking strength < 3.17 kg/sq cm: 0.11123243744783456
# Probability of breaking strength >= 3.6 kg/sq cm: 0.8246760551477705
# Probability of breaking strength between 5 and 5.5 kg/sq cm: 0.13055865981823633
# Probability of breaking strength NOT between 3 and 7.5 kg/sq cm: 0.13900157199868257

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

mean = 5
std_dev = 1.5
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 100)
y = stats.norm.pdf(x, mean, std_dev)
plt.plot(x, y, color='blue')
plt.fill_between(x[x < 3.17], y[x < 3.17], color='red')
plt.title('Breaking strength distribution')
plt.xlabel('Breaking strength (kg per sq cm)')
plt.ylabel('Probability density')
plt.show()

# %%
plt.plot(x, y, color='blue')
plt.fill_between(x[x >= 3.6], y[x >= 3.6], color='green')
plt.title('Breaking strength distribution')
plt.xlabel('Breaking strength (kg per sq cm)')
plt.ylabel('Probability density')
plt.show()

# %%
plt.plot(x, y, color='blue')
plt.fill_between(x[(x >= 5) & (x <= 5.5)], y[(x >= 5) & (x <= 5.5)], color='orange')
plt.title('Breaking strength distribution')
plt.xlabel('Breaking strength (kg per sq cm)')
plt.ylabel('Probability density')
plt.show()

# %% [markdown]
# 3.4. What proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm?

# %%
plt.plot(x, y, color='blue')
plt.fill_between(x[(x < 3) | (x > 7.5)], y[(x < 3) | (x > 7.5)], color='purple')
plt.title('Breaking strength distribution')
plt.xlabel('Breaking strength (kg per sq cm)')
plt.ylabel('Probability density')
plt.show()

# %% [markdown]
# Problem 4:
#
# Grades of the final examination in a training course are found to be normally distributed, with a mean of 77 and a standard deviation of 8.5. Based on the given information answer the questions below.
#
#
#
# 4.1 What is the probability that a randomly chosen student gets a grade below 85 on this exam?
#
# 4.2 What is the probability that a randomly selected student scores between 65 and 87?
#
# 4.3 What should be the passing cut-off so that 75% of the students clear the exam?

# %% [markdown]
# 4.1

# %%
from scipy.stats import norm

# mean and standard deviation
mu = 77
sigma = 8.5

# 4.1
prob_below_85 = norm.cdf(85, mu, sigma)
print("Probability of getting a grade below 85: {:.2f}%".format(prob_below_85*100))

# 4.2
prob_between_65_87 = norm.cdf(87, mu, sigma) - norm.cdf(65, mu, sigma)
print("Probability of getting a grade between 65 and 87: {:.2f}%".format(prob_between_65_87*100))

# 4.3
passing_cut_off = norm.ppf(0.75, mu, sigma)
print("Passing cut-off for 75% of students to clear the exam: {:.2f}".format(passing_cut_off))
# Out:
# Probability of getting a grade below 85: 82.67%
# Probability of getting a grade between 65 and 87: 80.13%
# Passing cut-off for 75% of students to clear the exam: 82.73

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mean = 77
std_dev = 8.5

x = np.arange(0, 101, 0.1)
y = norm.pdf(x, mean, std_dev)
plt.plot(x, y, color='blue')
plt.fill_between(x, y, where=(x<85), color='orange')
plt.title('Probability of getting a grade below 85')
plt.xlabel('Grade')
plt.ylabel('Probability density')
plt.show()

# %% [markdown]
# 4.2

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mean = 77
std_dev = 8.5

x = np.arange(0, 101, 0.1)
y = norm.pdf(x, mean, std_dev)
plt.plot(x, y, color='blue')
plt.fill_between(x, y, where=((x>=65) & (x<=87)), color='orange')
plt.title('Probability of getting a grade between 65 and 87')
plt.xlabel('Grade')
plt.ylabel('Probability density')
plt.show()

# %% [markdown]
# 4.3

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

mean = 77
std_dev = 8.5

# Define the normal distribution
dist = norm(mean, std_dev)

# Define x-values to use for plotting the curve
x = np.linspace(mean - 4 * std_dev, mean + 4 * std_dev, 1000)

# Plot the normal distribution curve
plt.plot(x, dist.pdf(x), color='blue')

# Shade the area under the curve that corresponds to the passing cut-off score
cutoff = dist.ppf(0.75)
plt.fill_between(x, 0, dist.pdf(x), where=(x >= cutoff), color='green')

# Add a vertical line to show the passing cut-off score
plt.axvline(x=cutoff, linestyle='--', color='black')

# Add labels and a title to the plot
plt.xlabel('Score')
plt.ylabel('Probability Density')
plt.title('Normal Distribution with Passing Cut-Off Score')

# Show the plot
plt.show()

# %% [markdown]
# Problem 5:
#
#
#
# Zingaro stone printing is a company that specializes in printing images or patterns on polished or unpolished stones. However, for the optimum level of printing of the image the stone surface has to have a Brinell's hardness index of at least 150. Recently, Zingaro has received a batch of polished and unpolished stones from its clients. Use the data provided to answer the following (assuming a 5% significance level);
#
#
#
# 5.1 Earlier experience of Zingaro with this particular client is favorable as the stone surface was found to be of adequate hardness. However, Zingaro has reason to believe now that the unpolished stones may not be suitable for printing. Do you think Zingaro is justified in thinking so?
#
# 5.2 Is the mean hardness of the polished and unpolished stones the same?

# %% [markdown]
# Solution:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import stats,ttest_1samp,ttest_ind

# %%
dataset = pd.read_csv('/content/Zingaro_Company.csv')

# %%
df = dataset.copy()

# %%
df.shape
# Out:
# (75, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unpolished            75 non-null     float64
#  1   Treated and Polished  75 non-null     float64
# dtypes: float64(2)
# memory usage: 1.3 KB

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#     Unpolished   Treated and Polished
# 0    164.481713            133.209393
# 1    154.307045            138.482771
# 2    129.861048            159.665201
# 3    159.096184            145.663528
# 4    135.256748            136.789227
# 5    161.820120            167.086582
# 6    149.455054            152.699641
# 7    135.714317            138.648766
# 8    102.004519            163.384427
# 9     89.482158            132.141726
# 10    95.349030            145.828526
# 11   104.421403            162.081613
# 12   140.889352            153.798449
# 13   147.366647            159.012005
# 14    48.406838            168.346223
# 15    68.251542            132.682955
# 16   126.169832            151.273875
# 17   130.436153            130.955804
# 18   120.894315            141.344288
# 19   107.275341            171.114662
# 20    64.575820            139.707672
# 21   136.650050            125.848600
# 22    94.631786            152.354527
# 23   154.670182            155.146849
# ...

# %%
from scipy.stats import ttest_1samp,ttest_ind
# Extract the hardness values for polished and unpolished stones
polished_stones = df['Unpolished '].values
unpolished_stones = df['Treated and Polished'].values

# 5.1: One-sample t-test for unpolished stones
alpha = 0.05  # Significance level

# Perform the one-sample t-test
t_statistic, p_value = ttest_1samp(unpolished_stones, 150, alternative='less')

# Compare the p-value with alpha
if p_value < alpha:
    print("p-value is :",p_value,"Zingaro has reason to believe that unpolished stones may not be suitable for printing.")
else:
    print("p-value is :",p_value,"Zingaro does not have sufficient evidence to believe that unpolished stones are unsuitable for printing.")

# 5.2: Two-sample t-test for mean hardness of polished and unpolished stones
alpha = 0.05  # Significance level

# Perform the two-sample t-test
t_statistic, p_value = ttest_ind(polished_stones, unpolished_stones)

# divide the p-value by 2 for a two-tailed t-test
p_value /= 2

# Compare the p-value with alpha
if p_value < alpha:
    print("p-value is :",p_value,"The mean hardness of polished and unpolished stones is different.")
else:
    print("p-value is :",p_value,"The mean hardness of polished and unpolished stones is the same.")
# Out:
# p-value is : 0.11149948416904217 Zingaro does not have sufficient evidence to believe that unpolished stones are unsuitable for printing.
# p-value is : 0.0007327575097314177 The mean hardness of polished and unpolished stones is different.

# %% [markdown]
# # Problem 6:
#
#  Aquarius health club, one of the largest and most popular cross-fit gyms in the country has been advertising a rigorous program for body conditioning. The program is considered successful if the candidate is able to do more than 5 push-ups, as compared to when he/she enrolled in the program. Using the sample data provided can you conclude whether the program is successful? (Consider the level of Significance as 5%)
#
# Note that this is a problem of the paired-t-test. Since the claim is that the training will make a difference of more than 5, the null and alternative hypotheses must be formed accordingly.

# %%
dataset = pd.read_csv('/content/Aquarius_gym.csv')

# %%
df=dataset.copy()

# %%
df
# Out:
#     Sr no.  Before  After
# 0        1      39     44
# 1        2      25     25
# 2        3      39     39
# 3        4       6     13
# 4        5      40     44
# 5        6      27     34
# 6        7      30     34
# 7        8      22     29
# 8        9      21     30
# 9       10      38     46
# 10      11      32     37
# 11      12      31     35
# 12      13      16     24
# 13      14      21     28
# 14      15      32     39
# 15      16      29     39
# 16      17      36     44
# 17      18      22     26
# 18      19      34     40
# 19      20      33     35
# 20      21      35     42
# 21      22      32     41
# 22      23      20     26
# 23      24      37     38
# 24      25      31     32
# 25      26      23     24
# 26      27      39     45
# 27      28      32     39
# 28      29      36     37
# 29      30      14     21
# 30      31      28     36
# 31      32      17     24
# 32      33      11     15
# 33      34      28     37
# ...

# %%
import pandas as pd
from scipy import stats

# Calculate the differences in push-ups
df['Difference'] = df['After'] - df['Before']

# Perform the paired t-test
t_statistic, p_value = stats.ttest_1samp(df['Difference'], 5, alternative='greater')

# Check the significance level
alpha = 0.05

# Print the t-statistic and p-value
print("T-Statistic:", t_statistic)
print("P-value:", p_value)

# Compare the p-value with the significance level
if p_value < alpha:
    print("The program is considered successful (Reject the null hypothesis)")
else:
    print("The program is not considered successful (Fail to reject the null hypothesis)")
# Out:
# T-Statistic: 1.9148542155126753
# P-value: 0.029198872141011217
# The program is considered successful (Reject the null hypothesis)

# %% [markdown]
# ## Problem 7:
#
#
# Dental implant data: The hardness of metal implant in dental cavities depends on multiple factors, such as the method of implant, the temperature at which the metal is treated, the alloy used as well as on the dentists who may favour one method above another and may work better in his/her favourite method. The response is the variable of interest.
#
# 1.Test whether there is any difference among the dentists on the implant hardness. State the null and alternative hypotheses. Note that both types of alloys cannot be considered together. You must state the null and alternative hypotheses separately for the two types of alloys.?
#
# 2.Before the hypotheses may be tested, state the required assumptions. Are the assumptions fulfilled? Comment separately on both alloy types.?
#
# 3.Irrespective of your conclusion in 2, we will continue with the testing procedure. What do you conclude regarding whether implant hardness depends on dentists? Clearly state your conclusion. If the null hypothesis is rejected, is it possible to identify which pairs of dentists differ?
#
# 4.Now test whether there is any difference among the methods on the hardness of dental implant, separately for the two types of alloys. What are your conclusions? If the null hypothesis is rejected, is it possible to identify which pairs of methods differ?
#
# 5.Now test whether there is any difference among the temperature levels on the hardness of dental implant, separately for the two types of alloys. What are your conclusions? If the null hypothesis is rejected, is it possible to identify which levels of temperatures differ?
#
# 6.Consider the interaction effect of dentist and method and comment on the interaction plot, separately for the two types of alloys?
#
# 7.Now consider the effect of both factors, dentist, and method, separately on each alloy. What do you conclude? Is it possible to identify which dentists are different, which methods are different, and which interaction levels are different?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import stats,ttest_1samp,ttest_ind
import scipy.stats as stats
from statsmodels.formula.api import ols

# %%
dataset = pd.read_excel('/content/Dental.xlsx')

# %%
df = dataset.copy()

# %%
df.isnull().sum()
# Out:
# Dentist     0
# Method      0
# Alloy       0
# Temp        0
# Response    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   90 non-null     int64
#  1   Method    90 non-null     int64
#  2   Alloy     90 non-null     int64
#  3   Temp      90 non-null     int64
#  4   Response  90 non-null     int64
# dtypes: int64(5)
# memory usage: 3.6 KB

# %%
df['Dentist']= pd.Categorical(df['Dentist'])
df['Method']= pd.Categorical(df['Method'])
df['Alloy']=pd.Categorical(df['Alloy'])
df['Temp']=pd.Categorical(df['Temp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   90 non-null     category
#  1   Method    90 non-null     category
#  2   Alloy     90 non-null     category
#  3   Temp      90 non-null     category
#  4   Response  90 non-null     int64
# dtypes: category(4), int64(1)
# memory usage: 1.8 KB

# %%
df
# Out:
#    Dentist Method Alloy  Temp  Response
# 0        1      1     1  1500       813
# 1        1      1     1  1600       792
# 2        1      1     1  1700       792
# 3        1      1     2  1500       907
# 4        1      1     2  1600       792
# 5        1      1     2  1700       835
# 6        1      2     1  1500       782
# 7        1      2     1  1600       698
# 8        1      2     1  1700       665
# 9        1      2     2  1500      1115
# 10       1      2     2  1600       835
# 11       1      2     2  1700       870
# 12       1      3     1  1500       752
# 13       1      3     1  1600       620
# 14       1      3     1  1700       835
# 15       1      3     2  1500       847
# 16       1      3     2  1600       560
# 17       1      3     2  1700       585
# 18       2      1     1  1500       715
# 19       2      1     1  1600       803
# 20       2      1     1  1700       813
# 21       2      1     2  1500       858
# ...

# %% [markdown]
# 7.1 Solution
#
# To test whether there is any difference among the dentists on the implant hardness for each type of alloy separately, you can perform an analysis of variance (ANOVA) test. Here are the null and alternative hypotheses for each type of alloy:
#
# For Alloy 1:
#
# Null Hypothesis (H0): There is no significant difference among the dentists on the implant hardness for Alloy 1.
# Alternative Hypothesis (H1): There is a significant difference among the dentists on the implant hardness for Alloy 1.
#
# Null Hypothesis (H0): μ1 = μ2 = μ3 = μ4 = μ5
# Alternative Hypothesis (H1): At least one of the means is different
#
# For Alloy 2:
#
# Null Hypothesis (H0): μ1 = μ2 = μ3 = μ4 = μ5
# Alternative Hypothesis (H1): At least one of the means is different
#
# Null Hypothesis (H0): There is no significant difference among the dentists on the implant hardness for Alloy 2.
# Alternative Hypothesis (H1): There is a significant difference among the dentists on the implant hardness for Alloy 2.
#
#
# In the formulas above:
#
# μ1, μ2, μ3, μ4, μ5 represent the mean implant hardness for dentists 1, 2, 3, 4, and 5, respectively.
# The null hypothesis assumes that there is no significant difference in the mean implant hardness among the dentists for a specific alloy, while the alternative hypothesis suggests that there is at least one dentist whose mean implant hardness differs from the others.

# %%
import pandas as pd
from scipy.stats import f_oneway

# Load the dataset
data = df.copy()

# Separate the data for Alloy 1 and Alloy 2
alloy1_data = data[data['Alloy'] == 1]
alloy2_data = data[data['Alloy'] == 2]

# Perform ANOVA test for Alloy 1
fvalue1, pvalue1 = f_oneway(alloy1_data['Response'][alloy1_data['Dentist'] == 1],
                            alloy1_data['Response'][alloy1_data['Dentist'] == 2],
                            alloy1_data['Response'][alloy1_data['Dentist'] == 3],
                            alloy1_data['Response'][alloy1_data['Dentist'] == 4],
                            alloy1_data['Response'][alloy1_data['Dentist'] == 5])

# Perform ANOVA test for Alloy 2
fvalue2, pvalue2 = f_oneway(alloy2_data['Response'][alloy2_data['Dentist'] == 1],
                            alloy2_data['Response'][alloy2_data['Dentist'] == 2],
                            alloy2_data['Response'][alloy2_data['Dentist'] == 3],
                            alloy2_data['Response'][alloy2_data['Dentist'] == 4],
                            alloy2_data['Response'][alloy2_data['Dentist'] == 5])

# Print the results
print("Alloy 1 - F-value:", fvalue1)
print("Alloy 1 - p-value:", pvalue1)
print("Alloy 2 - F-value:", fvalue2)
print("Alloy 2 - p-value:", pvalue2)
# Out:
# Alloy 1 - F-value: 1.9771119908770842
# Alloy 1 - p-value: 0.11656712140267628
# Alloy 2 - F-value: 0.5248351000282961
# Alloy 2 - p-value: 0.7180309510793431

# %% [markdown]
# For Alloy 1, the F-statistic is 1.9771119908770842 and the p-value is 0.11656712140267628, which suggests that there may be a significant difference in implant hardness among the dentists for Alloy 1, but we cannot reject the null hypothesis at the 0.05 significance level.There is some evidence of a difference among the groups, but it may not be strong enough to conclude that the difference is significant.
#
# For Alloy 2, the F-statistic is 0.5248351000282961 and the p-value is 0.7180309510793431, which suggests that there is not a significant difference in implant hardness among the dentists for Alloy 2, and we cannot reject the null hypothesis at the 0.05 significance level.

# %% [markdown]
# 7.2 Solution
#
# Assumptions of ANOVA :
#
# 1.Normality of the response variable: The Shapiro-Wilk test is used to check whether the response variable follows a normal distribution. The null hypothesis is that the data is normally distributed. If the p-value is greater than the significance level (usually 0.05), we cannot reject the null hypothesis.
#
# 2.Homoscedasticity: The Levene's test is used to check whether the variances of the response variable are equal across the levels of the categorical variable "Alloy". The null hypothesis is that the variances are equal. If the p-value is greater than the significance level, we cannot reject the null hypothesis.
#
# 3.Independence: We assume that the samples are independent if they are randomly selected or obtained through different dentists.
#
# 4.Normality of the residuals: The Shapiro-Wilk test is used to check whether the residuals (the differences between the predicted and observed values) follow a normal distribution. The null hypothesis is that the residuals are normally distributed. If the p-value is greater than the significance level, we cannot reject the null hypothesis.
#
#
#  Below code checks the four assumptions:

# %%
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import shapiro, levene, bartlett


# Separate the data by alloy type
alloy1 = df[df["Alloy"] == 1]['Response']
alloy2 = df[df["Alloy"] == 2]['Response']

#For Alloy 1 
resid = sm.formula.ols('Response ~ C(Dentist) + C(Method) + C(Alloy) + C(Temp)', data=df[df["Alloy"] == 1]).fit().resid
sm.qqplot(resid, line='s')
shapiro(resid)

stat, p = shapiro(resid)

# Print the test statistic and p-value
print('Shapiro-Wilk test statistic for Alloy 1: {:.4f}'.format(stat))
print('p-value: {:.4f}'.format(p))

#For Alloy 2 
resid = sm.formula.ols('Response ~ C(Dentist) + C(Method) + C(Alloy) + C(Temp)', data=df[df["Alloy"] == 2]).fit().resid
sm.qqplot(resid, line='s')
shapiro(resid)


stat, p = shapiro(resid)

# Print the test statistic and p-value
print('Shapiro-Wilk test statistic for Alloy 2: {:.4f}'.format(stat))
print('p-value: {:.4f}'.format(p))


# Check homogeneity of variance assumption
groups = df.groupby('Method')['Response'].apply(list)
stats.levene(*groups)

# Levene's Test for Homogeneity of Variances
levene1 = stats.levene(alloy1, alloy2)
print("Levene's Test for Alloy1: p-value = {:.4f}".format(levene1.pvalue))
levene2 = stats.levene(alloy1, alloy2)
print("Levene's Test for Alloy2: p-value = {:.4f}".format(levene2.pvalue))
if (levene1.pvalue > 0.05) & (levene2.pvalue > 0.05):
    print("The variances are approximately equal (p > 0.05)")
else:
    print("The variances are not equal (p < 0.05)")
# Out:
# Shapiro-Wilk test statistic for Alloy 1: 0.9738
# p-value: 0.3934
# Shapiro-Wilk test statistic for Alloy 2: 0.9887
# p-value: 0.9353
# Levene's Test for Alloy1: p-value = 0.2367
# Levene's Test for Alloy2: p-value = 0.2367
# The variances are approximately equal (p > 0.05)

# %% [markdown]
# 7.3 **To identify which pairs of dentists differ, we can perform a post-hoc test. One commonly used post-hoc test is the Tukey HSD test**, which can be performed using the statsmodels.stats.multicomp library. Here is an example code for performing the Tukey HSD test:

# %%
#for Alloy2
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = ols('Response ~ Dentist', data=alloy2_data).fit()
table = sm.stats.anova_lm(model, typ=2)
print(table)
# Out:
#                 sum_sq    df         F   PR(>F)
# Dentist   5.451361e+04   1.0  2.161465  0.14879
# Residual  1.084489e+06  43.0       NaN      NaN

# %%
#For Aloy 1
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = ols('Response ~ Dentist', data=alloy1_data).fit()
table = sm.stats.anova_lm(model, typ=2)
print(table)
# Out:
#                  sum_sq    df         F    PR(>F)
# Dentist    94802.677778   1.0  7.392027  0.009409
# Residual  551474.566667  43.0       NaN       NaN

# %% [markdown]
# From the ANOVA table, we can see that for Alloy1 the p-value for the Dentist variable is 0.009409, which is less than 0.05.  Therefore, we reject the null hypothesis and **conclude that there is a significant difference in mean implant hardness between at least two dentists**.
#
# But for Alloy 2 p-value >0.05 hence we cannot reject the null Hypothesis and there is no difference in the Dentists for Alloy2

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey = pairwise_tukeyhsd(alloy1_data['Response'], alloy1_data['Dentist'])
print(tukey.summary())
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   11.3333 0.9996 -145.0423  167.709  False
#      1      3  -32.3333 0.9757  -188.709 124.0423  False
#      1      4  -68.7778 0.7189 -225.1535  87.5979  False
#      1      5 -122.2222 0.1889 -278.5979  34.1535  False
#      2      3  -43.6667 0.9298 -200.0423  112.709  False
#      2      4  -80.1111 0.5916 -236.4868  76.2646  False
#      2      5 -133.5556 0.1258 -289.9312  22.8201  False
#      3      4  -36.4444 0.9626 -192.8201 119.9312  False
#      3      5  -89.8889 0.4805 -246.2646  66.4868  False
#      4      5  -53.4444 0.8643 -209.8201 102.9312  False
# --------------------------------------------------------

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey = pairwise_tukeyhsd(alloy2_data['Response'], alloy2_data['Dentist'])
print(tukey.summary())
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      1      2  -4.1111    1.0 -225.5687 217.3465  False
#      1      3 -36.5556 0.9895 -258.0131  184.902  False
#      1      4    -70.0 0.8941 -291.4576 151.4576  False
#      1      5 -90.1111 0.7724 -311.5687 131.3465  False
#      2      3 -32.4444 0.9933  -253.902 189.0131  False
#      2      4 -65.8889 0.9132 -287.3465 155.5687  False
#      2      5    -86.0 0.8008 -307.4576 135.4576  False
#      3      4 -33.4444 0.9925  -254.902 188.0131  False
#      3      5 -53.5556 0.9574 -275.0131  167.902  False
#      4      5 -20.1111  0.999 -241.5687 201.3465  False
# -------------------------------------------------------

# %% [markdown]
# The above result says there is no significant difference between the Dentists Type as the reject column shows False in every combination of Dentists Type

# %% [markdown]
# 7.4

# %%
alloy1_data = df[df['Alloy'] == 1]
alloy2_data = df[df['Alloy'] == 2]

import statsmodels.api as sm
from statsmodels.formula.api import ols

# Alloy1 ANOVA
alloy1_model = ols('Response ~ C(Dentist) + C(Method)', data=alloy1_data).fit()
alloy1_anova = sm.stats.anova_lm(alloy1_model, typ=2)
print("Alloy1 ANOVA:\n", alloy1_anova)

# Alloy2 ANOVA
alloy2_model = ols('Response ~ C(Dentist) + C(Method)', data=alloy2_data).fit()
alloy2_anova = sm.stats.anova_lm(alloy2_model, typ=2)
print("\nAlloy2 ANOVA:\n", alloy2_anova)
# Out:
# Alloy1 ANOVA:
#                     sum_sq    df         F    PR(>F)
# C(Dentist)  106683.688889   4.0  2.591255  0.051875
# C(Method)   148472.177778   2.0  7.212522  0.002211
# Residual    391121.377778  38.0       NaN       NaN
#
# Alloy2 ANOVA:
#                     sum_sq    df          F    PR(>F)
# C(Dentist)   56797.911111   4.0   0.926215  0.458933
# C(Method)   499640.400000   2.0  16.295479  0.000008
# Residual    582564.488889  38.0        NaN       NaN

# %% [markdown]
# Conclusion :
# The null hypothesis for each ANOVA is that there is no difference in the mean hardness among the methods and among the dentists for the given type of alloy. The alternative hypothesis is that there is at least one difference in the mean hardness among the methods or among the dentists.
#
# The output of the ANOVA shows that for
#
# Alloy1, Dentist  have no significant effect on the hardness of dental implant but Method has a significant effect on hardness of dental implant
#
# (p > 0.05 for Dentist factors and p < 0.05 for Method).
#
# For Alloy2, only Method has a significant effect on the hardness of dental implant
#
# (p < 0.05), while Dentist does not (p > 0.05).
#
# To identify which pairs of methods differ, we can perform Tukey's HSD post-hoc test for the significant factor in each ANOVA:

# %%
# Alloy1 Tukey HSD
alloy1_tukey = sm.stats.multicomp.pairwise_tukeyhsd(endog=alloy1_data['Response'], 
                                                     groups=alloy1_data['Method'], 
                                                     alpha=0.05)
print("Alloy1 Tukey HSD:\n", alloy1_tukey)

# Alloy2 Tukey HSD
alloy2_tukey = sm.stats.multicomp.pairwise_tukeyhsd(endog=alloy2_data['Response'], 
                                                     groups=alloy2_data['Method'], 
                                                     alpha=0.05)
print("\nAlloy2 Tukey HSD:\n", alloy2_tukey)
# Out:
# Alloy1 Tukey HSD:
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   -6.1333  0.987  -102.714  90.4473  False
#      1      3    -124.8 0.0085 -221.3807 -28.2193   True
#      2      3 -118.6667 0.0128 -215.2473  -22.086   True
# --------------------------------------------------------
#
# Alloy2 Tukey HSD:
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower     upper   reject
# --------------------------------------------------------
#      1      2     27.0 0.8212  -82.4546  136.4546  False
#      1      3   -208.8 0.0001 -318.2546  -99.3454   True
#      2      3   -235.8    0.0 -345.2546 -126.3454   True
# --------------------------------------------------------

# %% [markdown]
# The output of the Tukey HSD test shows which pairs of methods have a significant difference in the mean hardness, with a 95% confidence level
#
#
# So, we can see from above output that
#
# For Alloy1 :
#
# Method 1 and 3
# and    2 and 3 are showing significant difference on Metal hardness
#
#
# For Alloy2 :
#
# Again same combinations of Methods work

# %% [markdown]
# 7.5

# %% [markdown]
# Now test whether there is any difference among the temperature levels on the hardness of dental implant, separately for the two types of alloys. What are your conclusions? If the null hypothesis is rejected, is it possible to identify which levels of temperatures differ?

# %% [markdown]
# To test whether there is any difference among the temperature levels on the hardness of dental implant, we can perform a two-way ANOVA separately for each type of alloy.
#
# **The null hypothesis is that there is no difference in mean implant hardness among the different temperature levels for each type of alloy**
#
# **alternative hypothesis is that there is at least one temperature level that has a different mean implant hardness**.
#
#
# We can use the same approach as before to perform the two-way ANOVA and obtain the F-statistic and p-value for the effect of temperature on implant hardness, separately for each type of alloy.
#
# Here's the Python code to perform the two-way ANOVA for Alloy 1:

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols


# Filter the data for Alloy 1
df_alloy1 = df[df['Alloy'] == 1]
df_alloy2 = df[df['Alloy'] == 2]

# Fit the ANOVA model
model = ols('Response ~ C(Method) + C(Temp) + C(Method):C(Temp)', data=df_alloy1).fit()
model2 = ols('Response ~ C(Method) + C(Temp) + C(Method):C(Temp)', data=df_alloy2).fit()

# Perform the ANOVA
aov_table = sm.stats.anova_lm(model, typ=2)
aov_table2 = sm.stats.anova_lm(model2, typ=2)


# Print the ANOVA table
print(aov_table)
print(aov_table2)
# Out:
#                           sum_sq    df         F    PR(>F)
# C(Method)          148472.177778   2.0  5.641855  0.007390
# C(Temp)             10154.444444   2.0  0.385863  0.682642
# C(Method):C(Temp)   13959.022222   4.0  0.265217  0.898357
# Residual           473691.600000  36.0       NaN       NaN
#                           sum_sq    df          F    PR(>F)
# C(Method)          499640.400000   2.0  17.553524  0.000005
# C(Temp)             93748.933333   2.0   3.293617  0.048575
# C(Method):C(Temp)   33264.666667   4.0   0.584332  0.675983
# Residual           512348.800000  36.0        NaN       NaN

# %% [markdown]
# For Alloy 1, the p-value for the temperature effect is more than 0.05, so we cannot reject the null hypothesis and conclude that there is no significant difference in mean implant hardness among the different temperature levels for Alloy 1. However, the p-value for the interaction effect between method and temperature is not significant, so we cannot identify which pairs of methods differ.
#
# For Alloy 2 ,
#
# 'Method' and 'Temp' p-value < 0.05 , so it may have significant effect on metal hardness
#
# but no significant effect of  Method and Temperature together.

# %% [markdown]
#  here's the Python code to test whether there is any difference among the temperature levels on the hardness of dental implant, separately for the two types of alloys:

# %%
# Subset the data for Alloy 1
alloy1_data = df[df['Alloy'] == 1]

# Test for temperature levels on Alloy 1
model = ols('Response ~ C(Temp)', data=alloy1_data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)

# Subset the data for Alloy 2
alloy2_data = df[df['Alloy'] == 2]

# Test for temperature levels on Alloy 2
model = ols('Response ~ C(Temp)', data=alloy2_data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#                  sum_sq    df         F    PR(>F)
# C(Temp)    10154.444444   2.0  0.335224  0.717074
# Residual  636122.800000  42.0       NaN       NaN
#                 sum_sq    df         F    PR(>F)
# C(Temp)   9.374893e+04   2.0  1.883492  0.164678
# Residual  1.045254e+06  42.0       NaN       NaN

# %% [markdown]
# This will output two ANOVA tables, one for Alloy 1 and one for Alloy 2. Based on the p-values in these tables, we can conclude:
#
# For Alloy 1, the null hypothesis that there is no difference among the temperature levels on the hardness of dental implant is not rejected (p > 0.05).
# For Alloy 2, the null hypothesis that there is no difference among the temperature levels on the hardness of dental implant is not rejected (p > 0.05).

# %% [markdown]
# we can plot boxplots for the hardness of dental implants for each temperature level, separately for the two types of alloys, to visualize any differences among the levels.
#
# Here's the code to plot boxplots for Alloy1:

# %%
import seaborn as sns

sns.boxplot(x="Temp", y="Response", hue="Method", data=alloy1_data);

# %%
sns.boxplot(x="Temp", y="Response", hue="Method", data=alloy2_data);

# %% [markdown]
# The sns.boxplot() function from the Seaborn library creates a box plot of the hardness values for each temperature level, grouped by the method used. The x parameter specifies the variable to plot on the x-axis (temperature), the y parameter specifies the variable to plot on the y-axis (hardness), and the hue parameter specifies the variable to group the data by (method). The data parameter specifies the dataframe to use (either implant_alloy1 or implant_alloy2).
#
# We can then visually inspect the boxplots to see if there are any differences in hardness across temperature levels and methods, separately for each type of alloy. If there are significant differences, we can perform post-hoc tests to identify which temperature levels or pairs of methods differ.

# %% [markdown]
# For Alloy1 :
#
# Implants hardness is more at lower temperatures than higher temperatures for Method 3
#
# Implant hardness for Method 2 is decreasing with increase in temperature
#
# Implant hardness for Method 1 has almost similar hardness at different temperatures
#
#
# For Alloy 2:
#
# Implant Hardness for Method3 and Method 2 and Method 1 is reducing with increade in Temperature

# %% [markdown]
# 7.6 Consider the interaction effect of dentist and method and comment on the interaction plot, separately for the two types of alloys? solve this in python using the same dataset used above

# %%
import seaborn as sns

sns.set(style="ticks")

# create separate dataframes for each type of alloy
alloy1_df = df[df['Alloy']==1]
alloy2_df = df[df['Alloy']==2]

# plot interaction effect for alloy 1
A1=sns.catplot(x="Method", y="Response", hue="Dentist", data=alloy1_df, kind="point", dodge=True)
A1.set(title=" Interaction effect of dentist and method for Alloy 1")
plt.show()

# plot interaction effect for alloy 2
A2= sns.catplot(x="Method", y="Response", hue="Dentist", data=alloy2_df, kind="point", dodge=True)
A2.set(title=" Interaction effect of dentist and method for Alloy 2")
plt.show()

# %% [markdown]
# The interaction plot for Alloy1 shows that there is a significant interaction effect between the dentist and method. The pattern of differences among the dentists changes depending on the method used. For example, Dentist 1 has the highest implant hardness for Method 2, but the lowest implant hardness for Method 3. On the other hand, Dentist 4 has the highest implant hardness for Method 2, but the lowest implant hardness for Method 3.
#
# The interaction plot for Alloy2 also shows a significant interaction effect between the dentist and method. Similar to Alloy1, the pattern of differences among the dentists changes depending on the method used. For example, Dentist 1 has the highest implant hardness for Method 2, but the lowest implant hardness for Method 3. On the other hand, Dentist 4 has the highest implant hardness for Method 2, but the lowest implant hardness for Method 3.
#
# In conclusion, there is a significant interaction effect between the dentist and method for both types of alloys, and the pattern of differences among the dentists changes depending on the method used.

# %% [markdown]
# 7.7 Now consider the effect of both factors, dentist, and method, separately on each alloy. What do you conclude? Is it possible to identify which dentists are different, which methods are different, and which interaction levels are different? solve in python using above dataset

# %% [markdown]
# To test the effect of both factors, dentist, and method, separately on each alloy, we can perform a two-way ANOVA. The null hypothesis is that there is no significant difference in implant hardness among the dentists and methods, and their interaction effects. The alternative hypothesis is that there is a significant difference in at least one of the factors, and their interaction effects.
#
# We can use the ols function from the statsmodels library to fit the ANOVA model. Here's the code to perform the analysis for alloy 1:

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = ols('Response ~ C(Dentist) + C(Method) + C(Dentist):C(Method)', data=df_alloy1).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                              sum_sq    df          F    PR(>F)
# C(Dentist)            106683.688889   4.0   3.899638  0.011484
# C(Method)             148472.177778   2.0  10.854287  0.000284
# C(Dentist):C(Method)  185941.377778   8.0   3.398383  0.006793
# Residual              205180.000000  30.0        NaN       NaN

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = ols('Response ~ C(Dentist) + C(Method) + C(Dentist):C(Method)', data=df_alloy2).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                              sum_sq    df          F    PR(>F)
# C(Dentist)             56797.911111   4.0   1.106152  0.371833
# C(Method)             499640.400000   2.0  19.461218  0.000004
# C(Dentist):C(Method)  197459.822222   8.0   1.922787  0.093234
# Residual              385104.666667  30.0        NaN       NaN

# %% [markdown]
# The ANOVA table shows that there is a significant effect of dentist (p-value < 0.05) and method (p-value < 0.05) on implant hardness, but there is no significant interaction effect between the two factors (p-value > 0.05).
#
# To identify which dentists and methods are different, we can perform pairwise comparison tests using Tukey's HSD or Bonferroni correction.
#
# Here's the code to perform Tukey's HSD test for dentists on alloy 1:

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey = pairwise_tukeyhsd(endog=df_alloy1['Response'], groups=df_alloy1['Dentist'], alpha=0.05)
print(tukey.summary())
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   11.3333 0.9996 -145.0423  167.709  False
#      1      3  -32.3333 0.9757  -188.709 124.0423  False
#      1      4  -68.7778 0.7189 -225.1535  87.5979  False
#      1      5 -122.2222 0.1889 -278.5979  34.1535  False
#      2      3  -43.6667 0.9298 -200.0423  112.709  False
#      2      4  -80.1111 0.5916 -236.4868  76.2646  False
#      2      5 -133.5556 0.1258 -289.9312  22.8201  False
#      3      4  -36.4444 0.9626 -192.8201 119.9312  False
#      3      5  -89.8889 0.4805 -246.2646  66.4868  False
#      4      5  -53.4444 0.8643 -209.8201 102.9312  False
# --------------------------------------------------------

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey = pairwise_tukeyhsd(endog=df_alloy2['Response'], groups=df_alloy1['Dentist'], alpha=0.05)
print(tukey.summary())
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower    upper   reject
# -------------------------------------------------------
#      1      2  -4.1111    1.0 -225.5687 217.3465  False
#      1      3 -36.5556 0.9895 -258.0131  184.902  False
#      1      4    -70.0 0.8941 -291.4576 151.4576  False
#      1      5 -90.1111 0.7724 -311.5687 131.3465  False
#      2      3 -32.4444 0.9933  -253.902 189.0131  False
#      2      4 -65.8889 0.9132 -287.3465 155.5687  False
#      2      5    -86.0 0.8008 -307.4576 135.4576  False
#      3      4 -33.4444 0.9925  -254.902 188.0131  False
#      3      5 -53.5556 0.9574 -275.0131  167.902  False
#      4      5 -20.1111  0.999 -241.5687 201.3465  False
# -------------------------------------------------------

# %%
# Perform Tukey HSD test for Method factor on Alloy 1
import statsmodels.stats.multicomp as mc
tukey = mc.MultiComparison(df[df['Alloy']== 1]['Response'], df[df['Alloy']==1]['Method'])
tukey_result = tukey.tukeyhsd()
print(tukey_result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   -6.1333  0.987  -102.714  90.4473  False
#      1      3    -124.8 0.0085 -221.3807 -28.2193   True
#      2      3 -118.6667 0.0128 -215.2473  -22.086   True
# --------------------------------------------------------

# %%
# Perform Tukey HSD test for Method factor on Alloy 2
import statsmodels.stats.multicomp as mc
tukey = mc.MultiComparison(df[df['Alloy']== 2]['Response'], df[df['Alloy']==2]['Method'])
tukey_result = tukey.tukeyhsd()
print(tukey_result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower     upper   reject
# --------------------------------------------------------
#      1      2     27.0 0.8212  -82.4546  136.4546  False
#      1      3   -208.8 0.0001 -318.2546  -99.3454   True
#      2      3   -235.8    0.0 -345.2546 -126.3454   True
# --------------------------------------------------------

# %% [markdown]
# Based on the analysis of the dental implant dataset, we can conclude the following:
#
# For Alloy 1, the F-statistic is 1.9771119908770842 and the p-value is 0.11656712140267628, which suggests that there may be a significant difference in implant hardness among the dentists for Alloy 1, but we cannot reject the null hypothesis at the 0.05 significance level.There is some evidence of a difference among the groups, but it may not be strong enough to conclude that the difference is significant.
#
# For Alloy 2, the F-statistic is 0.5248351000282961 and the p-value is 0.7180309510793431, which suggests that there is not a significant difference in implant hardness among the dentists for Alloy 2, and we cannot reject the null hypothesis at the 0.05 significance level.
#
# There is a significant difference in implant hardness among the methods used for both types of alloys. The null hypothesis is rejected, and the alternative hypothesis is not rejected.
#
# There is a significant interaction effect of dentists and methods for both types of alloys. The interaction plot suggests that the dentists' effect on implant hardness varies depending on the method used, and the method effect varies depending on the dentist. For alloy 1, it seems that some dentists prefer method 2 over method 1, while for alloy 2, some dentists prefer method 1 over method 2.
#
#
# When considering the effect of both factors, dentist and method, separately for each alloy, we find that for alloy 1, dentists 1 and 2 tend to have higher implant hardness values than the other dentists. Additionally,
# For Alloy1 :
# Implants hardness is more at lower temperatures than higher temperatures for Method 3
#
# Implant hardness for Method 2 is decreasing with increase in temperature
#
# Implant hardness for Method 1 has almost similar hardness at different temperatures
#
# For Alloy 2:
#
# Implant Hardness for Method3 and Method 2 and Method 1 is reducing with increade in Temperature
#
#
# It is possible to identify which dentists, methods, and interaction levels are different using the appropriate post-hoc tests, as described above.
#
#
# For Alloy 1, the p-value for the temperature effect is more than 0.05, so we cannot reject the null hypothesis and conclude that there is no significant difference in mean implant hardness among the different temperature levels for Alloy 1. However, the p-value for the interaction effect between method and temperature is not significant, so we cannot identify which pairs of methods differ.
#
# For Alloy 2 ,
#
# 'Method' and 'Temp' p-value < 0.05 , so it may have significant effect on metal hardness
#
# but no significant effect of Method and Temperature together.
